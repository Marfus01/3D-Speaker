# %%
import numpy as np

# Define the speaker transition matrix logits
A_S_logits_full = np.array([
    [0., -0.2733921, -0.64527912, -1.26616073, 0.34751352, -2.13118369, -3.22291612, -2.97456522, -1.42110757, -1.04852643, -3.87086028],
    [-0.69273379, 0., -0.63993351, -1.2909685, -0.67442792, -2.42569691, -1.07787548, -1.99462575, -2.14955558, -3.37731985, -3.82553098],
    [-0.71047525, -0.34377501, 0., -1.2107976, -1.60855422, -1.00579923, -0.85217143, -3.10247677, -1.93828186, -1.97342809, -5.39512866],
    [-1.13835993, -0.61641276, -0.12417326, 0., -0.66841187, -2.24871081, 0.21976953, -2.33489899, -1.56236859, -2.00763215, -3.93695612],
    [0.78377922, -0.73670422, -0.61399151, -0.19702591, 0., -1.82518153, 0.9724786, -2.14353235, -2.35473323, -2.15474455, -3.67699251],
    [-1.6921406, -0.99528205, -2.57326718, -0.62645472, -0.56105747, 0., -1.3050612, -1.31252313, -1.12856972, -1.21312271, -2.50244519],
    [0.05173688, 0.44537081, 0.15115814, 0.23807027, 2.66285349, 0.38285006, 0., -0.77000722, -1.0397131, -0.98661979, 3.75252323],
    [-0.2989844, -1.39211091, 1.66129473, -0.53415477, -0.22556994, -1.17672735, -1.11274672, 0., 0.40748362, 5.2921107, -3.38922982],
    [-1.50998241, -2.18231666, -1.25042412, -2.55583254, -2.57523646, -1.44154024, -2.07646403, -1.6047704, 0., -1.63714008, -5.50549025],
    [-0.19195966, -3.55824253, -3.03110814, -2.38970245, -1.50074267, -1.32110094, -1.78367686, 3.90982633, -0.79553512, 0., -4.35404352],
    [-0.21560638, -0.74608305, 0.52703191, -0.84875928, -0.97758759, 0.06915578, 2.89734923, -1.51733313, -2.12080728, -1.4131895, 0.]
])


# Define the speaker recognition confusion matrix
B_S_full = np.array([
    [9.81187816e-01, 4.45583450e-03, 1.33085877e-05, 9.99998450e-07, 4.15780259e-04, 1.30176211e-02, 3.60669948e-04, 9.99998450e-07, 3.97385183e-04, 1.48584014e-04, 9.99998450e-07],
    [9.64638106e-03, 9.09803743e-01, 2.95358523e-02, 6.49659702e-03, 1.64558706e-06, 1.31814052e-02, 3.06709046e-02, 9.99998550e-07, 9.99998550e-07, 9.99998550e-07, 6.60471644e-04],
    [4.06862731e-05, 3.85592440e-03, 9.86006904e-01, 9.99997367e-07, 9.99997367e-07, 9.99997367e-07, 6.32144669e-03, 3.76649950e-03, 9.99997367e-07, 3.53872442e-06, 9.99997367e-07],
    [9.99998095e-07, 9.99998095e-07, 9.99998095e-07, 9.23558487e-01, 3.19817055e-02, 2.62880803e-02, 7.58745550e-03, 9.99998095e-07, 2.94125434e-03, 7.63801692e-03, 9.99998095e-07],
    [4.98206588e-01, 2.74641467e-05, 9.99998777e-07, 9.99998777e-07, 1.97138398e-01, 1.48811342e-06, 7.37556546e-02, 9.99998777e-07, 9.99998777e-07, 1.60131590e-01, 7.07348178e-02],
    [9.99995366e-07, 9.99995366e-07, 3.81044484e-06, 9.99995366e-07, 9.99995366e-07, 9.99987190e-01, 9.99995366e-07, 9.99995366e-07, 9.99995366e-07, 9.99995366e-07, 9.99995366e-07],
    [9.99998216e-07, 3.42341680e-02, 1.84024680e-03, 6.69498998e-04, 8.42278410e-01, 4.01589257e-02, 7.95350933e-02, 9.99998216e-07, 9.99998216e-07, 3.74036465e-06, 1.27691709e-03],
    [4.27488115e-02, 4.67851452e-01, 9.99998175e-07, 2.60197606e-02, 9.99998175e-07, 3.98522039e-03, 3.91306774e-02, 2.87500605e-01, 9.99998175e-07, 8.17122970e-02, 5.10481759e-02],
    [9.99995868e-07, 2.10274810e-02, 9.99995868e-07, 9.99995868e-07, 9.99995868e-07, 9.99995868e-07, 9.99995868e-07, 9.99995868e-07, 9.78963519e-01, 9.99995868e-07, 9.99995868e-07],
    [1.14967351e-02, 4.17201124e-01, 9.99998605e-07, 1.35663792e-02, 5.12116603e-03, 1.64926073e-02, 3.09829441e-02, 3.21833536e-01, 9.99998605e-07, 1.13293504e-01, 7.00100041e-02],
    [9.99998076e-07, 7.22324380e-02, 1.48686187e-02, 4.83321782e-02, 5.93532984e-01, 1.93219937e-02, 2.78006754e-02, 9.99998076e-07, 9.99998076e-07, 4.30393593e-03, 2.19604176e-01]
])


# Load the new speaker transition matrix logits
A_S_logits_hmmx = np.array([
    [0., -0.17971836, -0.23732562, -1.06385269, -1.49355632, -2.29223229, -0.07993623, 1.43621806, -0.75221971, 0.46409954, -3.97662662],
    [-0.40424504, 0., -0.01981337, -0.89105794, -3.12481352, -1.5016751, 0.82170643, -0.39309162, -1.93108952, 0.75707279, -4.98744043],
    [-0.73823654, -0.25248484, 0., -1.34920033, -1.92131976, -0.81124965, -3.55054404, -8.70022469, -1.69381636, -0.15990251, -7.84040812],
    [-1.04183034, -0.57621968, 0.02451188, 0., -1.86814618, -1.827771, -1.47146884, -4.1172216, -1.19591153, 1.02182042, -5.17527639],
    [-5.12281478, -15.60494213, -4.44522011, -6.673671, 0., -4.54149166, -11.47339001, -12.07978556, -11.61148434, -12.22263803, -14.89507996],
    [-4.25385481, -3.31459328, -4.67578631, -2.62336267, -9.59472873, 0., -5.87722837, -2.84496772, -3.19737126, -9.10796989, -13.01545354],
    [-5.9236483, -4.27983381, -3.99954572, -6.51481496, -4.66794385, -6.70513692, 0., -3.48264226, -3.04169594, -9.14272878, -6.27149399],
    [-2.49469985, -4.73703041, -3.68695912, -2.69741634, -3.92721507, -7.06651316, -8.35474355, 0., -4.84046962, -4.49404464, -10.10147414],
    [-2.06290181, -3.57943163, -1.59093436, -3.14299541, -2.53618209, -2.16823166, -0.41969502, -9.55173545, 0., -2.52366201, -13.18069631],
    [-3.71122566, -3.84668553, -3.62811905, -4.61339017, -11.52610794, -10.05190126, -10.94317082, -11.08321199, -12.44696126, 0., -6.80903689],
    [-3.63710329, -4.78479366, -4.33860798, -2.0966113, -9.7192744, -8.72091371, -7.26358823, -9.92466631, -10.39932148, -1.12248039, 0.]
])

# Load the new speaker recognition confusion matrix
B_S_hmmx = np.array([
    [9.85162263e-01, 9.99998288e-07, 7.35972369e-05, 9.99998288e-07, 3.73857202e-04, 1.39970694e-02, 9.99998288e-07, 9.99998288e-07, 3.62020437e-04, 2.61931652e-05, 9.99998288e-07],
    [6.97016004e-03, 9.00170024e-01, 3.94468068e-02, 1.22758320e-02, 2.94528287e-06, 1.01160232e-02, 3.10142083e-02, 9.99998340e-07, 9.99998340e-07, 9.99998340e-07, 9.99998340e-07],
    [6.92616652e-03, 4.83409464e-03, 9.76589447e-01, 9.99997938e-07, 9.99997938e-07, 9.99997938e-07, 6.15254554e-03, 5.49174604e-03, 9.99997938e-07, 9.99997938e-07, 9.99997938e-07],
    [9.99998943e-07, 1.13766858e-05, 1.86311727e-06, 9.26364544e-01, 2.83211906e-02, 3.01545857e-02, 7.97977053e-03, 9.99998943e-07, 2.43439691e-03, 4.72892963e-03, 1.34323477e-06],
    [1.14898648e-02, 4.00559790e-01, 9.99997640e-07, 3.51266654e-02, 5.15331646e-03, 6.50317534e-03, 1.95413374e-02, 5.14927606e-01, 9.99997640e-07, 9.99997640e-07, 6.69524496e-03],
    [9.99995525e-07, 9.99995525e-07, 1.95249087e-02, 1.95231115e-02, 9.99995525e-07, 9.39069016e-01, 2.18759636e-02, 9.99995525e-07, 9.99995525e-07, 9.99995525e-07, 9.99995525e-07],
    [7.31842827e-02, 7.46268000e-01, 9.99998678e-07, 2.57066767e-04, 9.47912713e-03, 2.04323837e-02, 1.10874008e-01, 9.99998678e-07, 9.99998678e-07, 4.18961172e-03, 3.53125193e-02],
    [6.72931211e-01, 1.71639086e-01, 9.99998671e-07, 1.35309948e-02, 9.99998671e-07, 4.09329465e-02, 2.35814840e-02, 9.99998671e-07, 9.99998671e-07, 2.13311865e-02, 5.60490910e-02],
    [1.24104027e-04, 1.70144647e-02, 9.99995890e-07, 9.99995890e-07, 9.99995890e-07, 9.99995890e-07, 9.99995890e-07, 9.99995890e-07, 9.82853431e-01, 9.99995890e-07, 9.99995890e-07],
    [8.84255639e-03, 9.99998454e-07, 1.19205531e-02, 3.82751312e-02, 7.43410566e-01, 2.75959295e-02, 1.90837722e-02, 9.99998454e-07, 9.99998454e-07, 1.50867492e-01, 9.99998454e-07],
    [3.19367998e-02, 1.34101861e-01, 1.74058068e-02, 9.15867859e-03, 2.98531159e-01, 1.30827376e-02, 3.03992757e-02, 9.99997555e-07, 9.99997555e-07, 9.99997555e-07, 4.65380681e-01]
])

# A_S_basic_full = np.exp(A_S_logits_full)

# %%
import matplotlib.pyplot as plt

# 创建一个包含两个子图的图形
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# 绘制 A_S_logits_full 的热力图
im1 = axes[0].imshow(A_S_logits_full, cmap='viridis', aspect='auto')
axes[0].set_title('A_S_logits_full')
fig.colorbar(im1, ax=axes[0])

# 绘制 A_S_logits_hmmx 的热力图
im2 = axes[1].imshow(A_S_logits_hmmx, cmap='viridis', aspect='auto')
axes[1].set_title('A_S_logits_hmmx')
fig.colorbar(im2, ax=axes[1])

# 添加整张图片的标题
fig.suptitle('Heatmap for A_S_logits', fontsize=16)

# 显示图形
plt.tight_layout()
plt.show()

# %%
# 创建一个包含两个子图的图形
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
# 绘制 B_S_full 的热力图
im1 = axes[0].imshow(B_S_full, cmap='viridis', aspect='auto')
axes[0].set_title('B_S_full')
fig.colorbar(im1, ax=axes[0])

# 绘制 B_S_hmmx 的热力图
im2 = axes[1].imshow(B_S_hmmx, cmap='viridis', aspect='auto')
axes[1].set_title('B_S_hmmx')
fig.colorbar(im2, ax=axes[1])

# 添加整张图片的标题
fig.suptitle('Heatmap for B_S', fontsize=16)

# 显示图形
plt.tight_layout()
plt.show()
